# %%
import Pkg; Pkg.add(["CSV", "DataFrames", "Plots"]); 
using CSV, DataFrames, Plots;
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.2/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.2/Manifest.toml`
#  [no changes]

# %%
df = CSV.File("./data/circuit.csv") |> DataFrame!
# Out:
# 5×5 DataFrame
# │ Row │ type   │ name   │ value │ startNode │ endNode │
# │     │ String │ String │ Int64 │ Int64     │ Int64   │
# ├─────┼────────┼────────┼───────┼───────────┼─────────┤
# │ 1   │ R      │ R1     │ 3     │ 0         │ 1       │
# │ 2   │ R      │ R2     │ 4     │ 1         │ 2       │
# │ 3   │ V      │ V1     │ 32    │ 3         │ 0       │
# │ 4   │ V      │ V2     │ 20    │ 3         │ 2       │
# │ 5   │ R      │ R3     │ 8     │ 3         │ 1       │

# %%
pi
# Out:
# π = 3.1415926535897...

# %% [markdown]
# # Learning Julia
#
# [reference](https://benlauwens.github.io/ThinkJulia.jl/latest/book.html)
#
# - for testing purposes, use:
#    - @assert
#    - @test
#
# - to see compiled assembly code:
#     - @code_native

# %%
[0:0.1:100;] |> x -> x.^2 |> plot

# %%
[0:0.1:100;] |> x -> sin.(x) |> plot

# %%
df
# Out:
# UndefVarError: df not defined
#
# Stacktrace:
#  [1] top-level scope at In[1]:1
